# %%
import numpy as np
test_arr = np.load("../results/whole_run_int/whole_run_int_run53-54.npy")

print(test_arr)
# Out:
# /xfel/ffs/dat/scan/run16_00001_DIR
# run16_00001 run16_00001
# /xfel/ffs/dat/scan/run16_00001_DIR /xfel/ffs/dat/scan/run16_00001_DIR/
# ...
